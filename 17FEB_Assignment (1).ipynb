# %%
"""
Q1. What is MongoDB? Explain non-relational databases in short. In which scenarios it is preferred to use
MongoDB over SQL databases?
ANS:---->

MongoDB is a popular document-oriented NoSQL database that uses a JSON-like 
document model to store data. Unlike traditional SQL databases, MongoDB is a non-relational database,
which means it does not use a structured table schema to organize and store data. 
Instead, it uses collections and documents to store data, which can have different fields and structures.

Non-relational databases, also known as NoSQL databases, are a type of database management 
system that do not use the traditional relational data model used in SQL databases. 
Instead, they use a variety of data models such as document, key-value, column-family,
and graph data models to store and manage data. Non-relational databases are often used
for large-scale and complex applications that require flexibility, scalability, and high performance.

MongoDB is preferred over SQL databases in several scenarios, including:

1.Applications that require high scalability: MongoDB is designed to handle 
large volumes of data and can be easily scaled horizontally to support the 
growing needs of an application.

2.Applications that require high availability: MongoDB supports automatic failover 
and replica sets, which ensures that data is always available and accessible, even in
the event of a node failure.

3.Applications that require flexible and dynamic data structures: MongoDB's document-oriented 
data model allows for flexible and dynamic data structures, making it ideal for applications 
that require frequently changing data structures.

4.Applications that require real-time analytics and reporting: MongoDB's aggregation 
framework and other built-in features make it easy to perform real-time analytics and
generate reports on large datasets.

In summary, MongoDB is a popular NoSQL database that is preferred over SQL databases in
scenarios that require high scalability, high availability, flexible data structures, and
real-time analytics and reporting.

          ======================================================================

Q2. State and Explain the features of MongoDB.
ANS:------>

MongoDB is a popular NoSQL database that offers several key features, including:

1.Flexible data model: MongoDB uses a document-oriented data model that allows for 
flexible and dynamic data structures. This means that data can be stored in a way that
makes sense for the application, rather than having to conform to a rigid table structure.

2.Scalability: MongoDB is designed to handle large volumes of data and can be easily scaled 
horizontally across multiple servers, making it ideal for applications that require high scalability.

3.High availability: MongoDB supports automatic failover and replica sets, which ensure that data
is always available and accessible, even in the event of a node failure.

4.Indexing and querying: MongoDB supports efficient indexing and querying, making it easy
to search and retrieve data from large datasets.

5.Aggregation and reporting: MongoDB's aggregation framework and other built-in 
features make it easy to perform real-time analytics and generate reports on large datasets.

6.Support for geospatial data: MongoDB includes support for geospatial data, making it
easy to work with location-based data.

7.Multi-document transactions: MongoDB supports multi-document transactions, 
which allows for multiple operations to be grouped together and executed as a single transaction.

8.Horizontal scalability: MongoDB supports sharding, which enables horizontal scaling of
the database across multiple machines, enabling better performance and throughput.

9.Document validation: MongoDB supports document validation to ensure that documents 
conform to specific rules, enabling the database to maintain data quality.

Overall, MongoDB's features make it a powerful and flexible NoSQL database that is 
ideal for applications that require scalability, availability, and efficient data management.

             ==============================================================
"""
"""Q3. Write a code to connect MongoDB to Python. Also, create a database and a collection in MongoDB.
ANS:----->

Here is an example Python code that demonstrates how to connect to a MongoDB instance,
create a new database, and create a new collection within that database:"""

import pymongo

# connect to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")

# create a new database
mydb = client["mydatabase"]

# create a new collection in the database
mycol = mydb["customers"]

# add a document to the collection
mydict = { "name": "John", "address": "Highway 37" }
x = mycol.insert_one(mydict)

# print the ID of the inserted document
print(x.inserted_id)


#In this example, we first import the pymongo module and then create a MongoClient
#instance to connect to a MongoDB instance running on the local machine (on the default port of 27017).
#We then create a new database called mydatabase and a new collection within that database called customers.
#Finally, we add a new document to the customers collection and print the ID of the inserted document.

 #     =====================================================================
    
"""Q4. Using the database and the collection created in question number 3, write a code to insert one record,
and insert many records. Use the find() and find_one() methods to print the inserted record.
ANS:------>

Here is an example Python code that demonstrates how to insert one record and multiple records
into a MongoDB collection, and then use the find() and find_one() methods to print the inserted record(s):"""

import pymongo

# connect to MongoDB and select database and collection
client = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = client["mydatabase"]
mycol = mydb["customers"]

# insert one record
mydict = { "name": "Alice", "address": "123 Main Street" }
x = mycol.insert_one(mydict)
print("Inserted record with ID:", x.inserted_id)

# insert multiple records
mylist = [
  { "name": "Bob", "address": "456 Oak Avenue" },
  { "name": "Charlie", "address": "789 Elm Boulevard" },
  { "name": "Dave", "address": "321 Pine Drive" }
]
x = mycol.insert_many(mylist)
print("Inserted", len(x.inserted_ids), "records")

# find one record
record = mycol.find_one({ "name": "Alice" })
print("Found one record:", record)

# find all records
records = mycol.find()
print("Found", records.count(), "records:")
for record in records:
    print(record)

    
 """   =========================================================================
    
Q5. Explain how you can use the find() method to query the MongoDB database. Write a simple code to
demonstrate this.


In MongoDB, the find() method is used to retrieve documents from a collection 
that match a certain query. The method takes a query object as its argument, 
which specifies the search criteria. Here is an example code that demonstrates 
how to use the find() method in Python to query a MongoDB database:
"""
import pymongo

# connect to MongoDB and select database and collection
client = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = client["mydatabase"]
mycol = mydb["customers"]

# define a query object
query = { "name": "Alice" }

# execute the query using the find() method
results = mycol.find(query)

# iterate over the results and print each document
for result in results:
    print(result)
    
    """
In this example, we first connect to the MongoDB instance and select the mydatabase
database and the customers collection. We then define a query object that specifies
the search criteria. The query object is a dictionary that maps field names to their desired values.
In this case, we want to find all documents where the name field is "Alice". We then pass the query
object to the find() method, which returns a cursor object that contains the matching documents. 
We iterate over the cursor using a for loop and print each document. Note that if we omit the query
object from the find() method, it will return all documents in the collection.
"""

 #      =======================================================================
"""
Q6. Explain the sort() method. Give an example to demonstrate sorting in MongoDB.
ANS:------>
In MongoDB, the sort() method is used to sort the documents in a collection based on one
or more fields. The method takes a sorting object as its argument, which specifies the fields 
to sort on and the sort order for each field. Here is an example code that demonstrates how to
use the sort() method in Python to sort a MongoDB collection:
    """
import pymongo

# connect to MongoDB and select database and collection
client = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = client["mydatabase"]
mycol = mydb["customers"]

# define a sorting object
sort_order = [("name", 1), ("age", -1)]

# execute the sort using the sort() method
results = mycol.find().sort(sort_order)

# iterate over the results and print each document
for result in results:
    print(result)

    """In this example, we first connect to the MongoDB instance and select the 
    mydatabase database and the customers collection. We then define a sorting object
    that specifies the fields to sort on and the sort order for each field. 
    The sorting object is a list of tuples, where each tuple specifies a field name and a sort order.
    In this case, we want to sort the documents first by the name field in ascending order (1), 
    and then by the age field in descending order (-1). We then pass the sorting object to the 
    sort() method, which returns a cursor object that contains the sorted documents. We iterate
    over the cursor using a for loop and print each document. Note that if we omit the sorting 
    object from the sort() method, it will sort the documents in ascending 
    order by the _id field by default."""

   # =======================================================================
"""
Q7. Explain why delete_one(), delete_many(), and drop() is used.
ANS:------->
In MongoDB, the delete_one() and delete_many() methods are used to remove one or 
multiple documents from a collection, respectively. The drop() method is used to drop
the entire collection. Here's a brief explanation of when each of these methods is used:

1.delete_one(): This method is used to delete a single document that matches a specified filter. 
For example, if we want to delete a document with a specific _id value, we can use the 
following code: mycol.delete_one({"_id": ObjectId("612f98148e4b4c4b787482af")}). This method will delete the first document that matches the specified filter.

delete_many(): This method is used to delete multiple documents that match a specified filter. For example, if we want to delete all documents with a specific field value, we can use the following code: mycol.delete_many({"field": "value"}). This method will delete all documents that match the specified filter.

drop(): This method is used to drop the entire collection. This means that all the documents in the collection will be permanently deleted, and the collection itself will be removed. This method is typically used when we no longer need a collection or when we want to start fresh with a new collection. For example, we can use the following code to drop the mycol collection: mycol.drop().

It's important to note that these methods can have serious consequences if used incorrectly, as they can permanently delete data from the database. Therefore, it's recommended to use these methods with caution and to always make a backup of the data before performing any deletions.
